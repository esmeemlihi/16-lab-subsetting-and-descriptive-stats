# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import numpy as np 
import pandas as pd 
import matplotlib
import math
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp_states = pd.read_csv('temp_states.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp_states
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here

'''
L.S. Correct!
'''

"""
There are 3 columns with 3 types of data 

column city = string (or categorical? if there is only a short lost of cities)
column state = string (or categorical? if there is only a short lost of states)
column tempratufte = float  
"""
# Out:
# '\nThere are 3 columns with 3 types of data \n\ncolumn city = string (or categorical? if there is only a short lost of cities)\ncolumn state = string (or categorical? if there is only a short lost of states)\ncolumn tempratufte = float  \n'

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here

'''
L.S. Correct!
'''

temp_states[temp_states.State == 'New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here

'''
L.S. Good!
'''

(temp_states[temp_states.State == 'New York']).describe()
# the mean is 10.740741
# Out:
#        Temperature
# count     3.000000
# mean     10.740741
# std       8.133404
# min       3.333333
# 25%       6.388889
# 50%       9.444444
# 75%      14.444444
# max      19.444444

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here

'''
L.S. Indeed!
'''

temp_states[temp_states.Temperature >15][["City", "State"]]
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here

temp_states[temp_states.Temperature >15]["City"]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here

'''
L.S. Correct, but there is an easier way of doing this: just combine the two lines of code.
'''

temp_15 = temp_states[temp_states.Temperature > 15]
temp_15_20 = temp_15[temp_15.Temperature < 20]

temp_15_20.City
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
# this option via buckets did not work...
#city_labels = ['New York', 'Connecticut', 'New Jersey']
#bins = pd.cut(temp_states_cities ['State'],3, labels=city_labels)

# and this option is to long 
temp_states = temp_states[["State", "Temperature"]]
temp_states[temp_states.State == "New York"].describe()[1:3]
temp_states[temp_states.State == "Connecticut"].describe()[1:3]
temp_states[temp_states.State == "New Jersey"].describe()[1:3]
# Out:
#       Temperature
# mean    21.111111
# std      1.571348

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here

'''
L.S. Correct!
'''

employee =pd.read_csv('employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
print(
        "Name: ", type(employee.Name[1]), 
        "\nDepartment = categorical: ", type(employee.Department[1]),
        "\nEducation = categorical: ", type(employee.Education[1]),
        "\nGender = categorical: ", type(employee.Gender[1]),
        "\nTitle categorical: ", type(employee.Title[1]),
        "\nYears: ", type(employee.Years[1]),
        "\nSalary: ", type(employee.Salary[1])   
     )
# Out:
# Name:  <class 'str'>
# Department = categorical:  <class 'str'>
# Education = categorical:  <class 'str'>
# Gender = categorical:  <class 'str'>
# Title categorical:  <class 'str'>
# Years:  <class 'numpy.int64'>
# Salary:  <class 'numpy.int64'>

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here

'''
L.S. Good!
'''

employee.hist(bins=20)

"""
YEARS
The most eployees have worked between 1-4 years at the company, there is a gap between 4 and 8 years. 
This could mean that at 4 years lots op people leave and that the company is 8 years old. 

SALARY 
Personel that works in the same time frame has probaly the same amound of salary?..

"""
# Out:
# '\nYEARS\nThe most eployees have worked between 1-4 years at the company, there is a gap between 4 and 8 years. \nThis could mean that at 4 years lots op people leave and that the company is 8 years old. \n\nSALARY \nPersonel that works in the same time frame has probaly the same amound of salary?..\n\n'

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here

'''
L.S. Correct!
'''

print("The avareage salary is: ", int(employee.Salary.mean()))
# Out:
# The avareage salary is:  48

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
print("The max salary is: ", int(employee.Salary.max()))
# Out:
# The max salary is:  70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
print("The min salary is: ", int(employee.Salary.min()))
# Out:
# The min salary is:  30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here

'''
L.S. Very good!
'''

employee.Salary

Lowes_earners= employee[employee.Salary < 31]['Name']
print("The lowest earners are: \n", Lowes_earners)
# Out:
# The lowest earners are:
#  1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[2:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee.loc[2:2, ['Name','Salary']]
# Out:
#     Name  Salary
# 2  David      30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here

'''
L.S. Nice!
'''

title_associate = employee[employee.Title =='associate']
title_associate
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee[:2]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30

# %%
# your answer here- 2nd method
employee.head(2)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
# Salaray_above55 = title_associate[title_associate.Salary > 55] 
Salaray_above55 = (employee[employee.Title =='associate'])[title_associate.Salary > 55]
Salaray_above55
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here

'''
L.S. True!
'''

employee.groupby(employee['Years']).mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
(employee.groupby(employee['Title']).mean()).Salary
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()


'''
L.S. Correct!
'''

'''
|--[ I ]---|

|- = the min value (first value)
[ = the first Quartile 
I = the value exactly at the midle (seccond quartile)
] = the Thirt quartile 
-| = the max value (last value)

YEARS:
Quartile 1 = prox 2 
Quartile 3 = prox 7 

SALARY

Quartile 1 = prox 35
Quartile 3 = prox 60

'''
# Out:
# '\n|--[ I ]---|\n\n|- = the min value (first value)\n[ = the first Quartile \nI = the value exactly at the midle (seccond quartile)\n] = the Thirt quartile \n-| = the max value (last value)\n\nYEARS:\nQuartile 1 = prox 2 \nQuartile 3 = prox 7 \n\nSALARY\n\nQuartile 1 = prox 35\nQuartile 3 = prox 60\n\n'

# %%
# print first quartile here
employee.describe()[4:5]
# Out:
#      Years  Salary
# 25%    2.0    35.0

# %%
# print third quartile here
employee.describe()[6:7]
# Out:
#      Years  Salary
# 75%    7.0    60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
'''
L.S. Correct!
'''

# your answer here
# yes, females earn les then men 
(employee.groupby(employee['Gender']).mean()).Salary
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee_Department= employee.groupby(employee['Department'])
employee_Department.describe()
# Out:
#            Years                                                Salary         \
#            count      mean       std  min   25%  50%   75%  max  count   mean
# Department
# HR           3.0  4.666667  3.055050  2.0  3.00  4.0  6.00  8.0    3.0  45.00
# IT           4.0  4.500000  3.511885  1.0  1.75  4.5  7.25  8.0    4.0  48.75
# Sales        2.0  2.500000  0.707107  2.0  2.25  2.5  2.75  3.0    2.0  55.00
#
#
#                   std   min    25%   50%   75%   max
# Department
# HR          21.794495  30.0  32.50  35.0  52.5  70.0
# IT          19.311050  30.0  33.75  47.5  62.5  70.0
# Sales        0.000000  55.0  55.00  55.0  55.0  55.0

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders=pd.read_csv('Orders.csv')
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
# your answer here

'''
L.S. Correct!
'''

"""
The data set is shows an overvieuw of invoices.
These price of the invoices can be qiet different. Visbale via teh max and min and stv of 309 
The min-max of the year shows that the invoices are from 2010 and 2011 --> so probabaly one year in total?  
"""
# Out:
# '\nThe data set is shows an overvieuw of invoices.\nThese price of the invoices can be qiet different. Visbale via teh max and min and stv of 309 \nThe min-max of the year shows that the invoices are from 2010 and 2011 --> so probabaly one year in total?  \n'

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
print("the avarage Purchiase price is: ", int(orders.amount_spent.mean()))
# Out:
# the avarage Purchiase price is:  22

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
print("The lowest ordered price is: ", orders.amount_spent.min())
# Out:
# The lowest ordered price is:  0.0

# %%
# your answer here
print("The highest ordered price is: ", orders.amount_spent.max())
# Out:
# The highest ordered price is:  168469.6

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders_spain = orders[orders.Country == "Spain"]
orders_spain
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here

'''
L.S. Very good!
'''

spain_CustomerID= orders_spain.groupby(orders_spain['CustomerID'])
print("there are ", len(spain_CustomerID), " unique Customer ID's from spain.")
spain_CustomerID.count()
# Out:
# there are  30  unique Customer ID's from spain.
#             Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  \
# CustomerID
# 12354               58         58         58    58     58   58    58
# 12417               23         23         23    23     23   23    23
# 12421               45         45         45    45     45   45    45
# 12442               12         12         12    12     12   12    12
# 12445                4          4          4     4      4    4     4
# 12448               22         22         22    22     22   22    22
# 12450                8          8          8     8      8    8     8
# 12454               15         15         15    15     15   15    15
# 12455               48         48         48    48     48   48    48
# 12462               62         62         62    62     62   62    62
# 12484              346        346        346   346    346  346   346
# 12502              147        147        147   147    147  147   147
# ...

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here


'''
L.S. Very nice!
'''

orders_spain_Quantity = orders[(orders.Country == "Spain") & (orders.Quantity  > 50)]    
orders_spain_Quantity_CustomerID = orders_spain_Quantity.groupby(orders_spain_Quantity['CustomerID'])

orders_spain_Quantity_CustomerID["CustomerID"].count()
# Out:
# CustomerID
# 12454     4
# 12484     1
# 12507     5
# 12546     1
# 12557    24
# 12596     1
# 12597     3
# Name: CustomerID, dtype: int64

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here

orders_spain_Quantity = orders[(orders.Country == "Spain") & (orders.Quantity  > 50)]

# %% [markdown]
# #### Select all free orders

# %%
# your answer here

orders_spain_free = orders[(orders.UnitPrice == 0)] 
orders_spain_free.head(2)
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914         9302     537197     22841  2010     12    7    14
# 22539       33576     539263     22580  2010     12    4    14
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 6914   round cake tin vintage green         1  2010-12-05 14:02:00        0.0
# 22539  advent calendar gingham sack         4  2010-12-16 14:36:00        0.0
#
#        CustomerID         Country  amount_spent
# 6914        12647         Germany           0.0
# 22539       16560  United Kingdom           0.0

# %%
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here

'''
L.S. Nice!
'''

import re

string_list_lunch = ''.join(list(orders["Description"])) # to make on string of the description column 
pattern = '[\w]+ lunch bag' # [\w]+  to find the description above the "lunch box" tag for a index check in the table later 

re.findall(pattern, string_list_lunch)
# Out:
# ['white lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'woodland lunch bag',
#  'design lunch bag',
#  'box lunch bag',
#  'design lunch bag',
#  'spot lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'polkadots lunch bag',
#  'design lunch bag',
#  'star lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'ball lunch bag',
#  'sign lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'box lunch bag',
#  'santas lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'notebook lunch bag',
#  'woodland lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'design lunch bag',
#  'globe lunch bag',
#  'card lunch bag',
#  'retrospot lunch bag',
#  'fairy lunch bag',
#  'design lunch bag',
#  'design lunch bag',
# ...

# %%
orders_lunchbag = orders[(orders.Description == "lunch bag")]   
orders_lunchbag # the plot is empty?? but we know base on the regex check there are many lunch bag order descriptions...
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, InvoiceNo, StockCode, year, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, amount_spent]
# Index: []

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders_2011_lunch = orders[(orders.year == 2011)] #& lunch selection 
orders_2011_lunch
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26160        42481     539993     22386  2011      1    2    10
# 26161        42482     539993     21499  2011      1    2    10
# 26162        42483     539993     21498  2011      1    2    10
# 26163        42484     539993     22379  2011      1    2    10
# 26164        42485     539993     20718  2011      1    2    10
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                             Description  Quantity          InvoiceDate  \
# 26160           jumbo bag pink polkadot        10  2011-01-04 10:00:00
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
'''
L.S. Correct, but why bins = 100?
'''

# your answer here
orders_spain.amount_spent.hist(bins=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-b582a80e7cad> in <module>()
#       1 # your answer here
# ----> 2 orders_spain.amount_spent.hist(bins=20)
#
# NameError: name 'orders_spain' is not defined

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders_august = orders[(orders.month == 8)]
orders_august
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders_august_coutry = orders_august.groupby(orders_august['Country'])

orders = len(orders_august_coutry["Quantity"])
#print("In Agust there where %f orders" % orders )
print("In Agust there where: ", orders, "orders" )
# Out:
# In Agust there where:  23 orders

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here

'''
L.S. Correct!
'''

orders_country = orders.groupby(orders['Country'])
orders_country["amount_spent"].mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

'''
L.S. Correct, but without the minus at the end!
'''

orders_country["amount_spent"].max()
print("UK orderd the most expensive item of 168469.60-")
# Out:
# UK orderd the most expensive item of 168469.60-

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders_year_amound = orders[['year','amount_spent']]
print(orders_year_amound[(orders_year_amound.year == 2010)].describe()[1:2])
print(orders_year_amound[(orders_year_amound.year == 2011)].describe()[1:2])
# Out:
#         year  amount_spent
# mean  2010.0     21.892733
#         year  amount_spent
# mean  2011.0     22.430074
